# %%
1.3.1  Data Visualization
My goal now is to better visualize the relations between the regions and the ammenities that the properties offer as well as the relationship between the regions and prices of the properties. I would like to disect my dataset in a way to identify the best predictors of prices and the most important ammenities for location of the properties.

The box plot below shows how extremely high the prices in the Central region are compared to everywhere else even though median prices seem relatively stable.

1
​
2
from tabulate import tabulate
3
placessmall = places.iloc[1:1850, 3:6]
4
t = placessmall.describe()
5
print(tabulate(t,headers='firstrow'))
6
​
count      1849.0
-------  --------
mean     2.52136
std      0.681149
min      1
25%      2
50%      2
75%      3
max      5
1
#Box plots of prices by region
2
fig = plt.figure(figsize= (10, 10))
3
ax = fig.add_subplot(111)
4
green_diamond = dict(markerfacecolor='g', marker='D')
5
​
6
ax.set_title("Box Plots of Prices by Region", fontsize= 20)
7
ax.set
8
​
9
data = [  places['Price'][places['Region'] == 'Central'],
10
               places['Price'][places['Region'] == 'West'],
11
               places['Price'][places['Region'] == 'Southeast'],
12
               places['Price'][places['Region'] == 'East'],
13
               places['Price'][places['Region'] == 'Northeast'],
14
               places['Price'][places['Region'] == 'North'],
15
               places['Price'][places['Region'] == 'South']]
16
​
17
ax.boxplot(data, flierprops=green_diamond, notch=True,
18
           labels= ['Central','West', 'Southeast', 'East', 'Northeast', 'North', 'South'],
19
           showmeans= True)
20
​
21
plt.xlabel("Region")
22
plt.ylabel("House Prices")
23
​
24
plt.show()

All the extreme outliers are in the Central region while the rest of the properties that are located in all other regions have prices that are closer to the mean. The West and Northeast regions have the most uniformed prices towards the lower end.

1
#box plots of number of entertainment sites per region
2
fig = plt.figure(figsize= (10, 10))
3
ax = fig.add_subplot(111)
4
green_diamond = dict(markerfacecolor='g', marker='D')
5
​
6
ax.set_title("Box Plots of Entertain by Region", fontsize= 20)
7
ax.set
8
​
9
data = [  places['Entertain'][places['Region'] == 'Central'],
10
               places['Entertain'][places['Region'] == 'West'],
11
               places['Entertain'][places['Region'] == 'Southeast'],
12
               places['Entertain'][places['Region'] == 'East'],
13
               places['Entertain'][places['Region'] == 'Northeast'],
14
               places['Entertain'][places['Region'] == 'North'],
15
               places['Entertain'][places['Region'] == 'South']]
16
​
17
ax.boxplot(data, notch=True, flierprops=green_diamond,
18
           labels= ['Central','West', 'Southeast', 'East', 'Northeast', 'North', 'South'],
19
           showmeans= True)
20
​
21
plt.xlabel("Region")
22
plt.ylabel("Ares Entertainment")
23
​
24
plt.show()

1
#box plots of sqft of area by region
2
fig = plt.figure(figsize= (10, 10))
3
ax = fig.add_subplot(111)
4
green_diamond = dict(markerfacecolor='g', marker='D')
5
ax.set_title("Apartment sizes(sqft) by Region", fontsize= 20)
6
ax.set
7
​
8
data = [  places['Area'][places['Region'] == 'Central'],
9
               places['Area'][places['Region'] == 'West'],
10
               places['Area'][places['Region'] == 'Southeast'],
11
               places['Area'][places['Region'] == 'East'],
12
               places['Area'][places['Region'] == 'Northeast'],
13
               places['Area'][places['Region'] == 'North'],
14
               places['Area'][places['Region'] == 'South']]
15
​
16
ax.boxplot(data,notch=True, flierprops=green_diamond,
17
           labels= ['Central','West', 'Southeast', 'East', 'Northeast', 'North', 'South'],
18
           showmeans= True)
19
​
20
plt.xlabel("Region")
21
plt.ylabel("Apartment sizes")
22
​
23
plt.show()

Type Markdown and LaTeX: 𝛼2
1
fig = plt.figure(figsize= (10, 10))
2
ax = fig.add_subplot(111)
3
ax.set_title("Number of Apartments by Region", fontsize= 20)
4
ax.set
5
ax.hist(places["Region"], color ='maroon', bins=7, edgecolor="white"
6
        )
7
plt.xlabel("Region")
8
plt.ylabel("Number of properties")
9
​
10
plt.show()

1
fig = plt.figure(figsize= (10, 10))
2
ax = fig.add_subplot(111)
3
ax.set_title("Number of Fitness ammenities near property", fontsize= 20)
4
ax.set
5
ax.hist(places["Fitness"], color ='maroon', bins=7, edgecolor="white"
6
        )
7
plt.xlabel("Number of ammenities")
8
plt.ylabel("Properties")
9
​
10
plt.show()

1
fig = plt.figure(figsize= (10, 10))
2
ax = fig.add_subplot(111)
3
ax.set_title("Size of the property", fontsize= 20)
4
ax.set
5
ax.hist(places["Area"], color ='maroon', bins=7, edgecolor="white"
6
        )
7
plt.xlabel("SqFt")
8
plt.ylabel("Properties")
9
​
10
plt.show()

1
fig = plt.figure(figsize= (10, 10))
2
ax = fig.add_subplot(111)
3
ax.set_title("Number of Bedrooms per property", fontsize= 20)
4
ax.set
5
ax.hist(places["Bedrooms"], color ='maroon', bins=7, edgecolor="white"
6
        )
7
plt.xlabel("Number of bedrooms")
8
plt.ylabel("Properties")
9
​
10
plt.show()

The following histograms are to get an idea of the distrubution of fitness centers, area, and number of bedrooms in the dataset.

1.4  Correlation Analysis
I'm reviewing the different variables in order to identify possible correlation between different variables. For example I'd expect that properties with a jogging track and gymnasium to also include a swimming pool. I'd would like to identify variables that show multicolinearity to ensure that they do not affect our linear model. Due to the fact of having more than 40 different variables, reviewing the matrix manually is difficult. This is why we also decided to create a headmap that appears under the table.

1
places.corr()
UID	Price	Area	Bedrooms	Resale	MaintenanceStaff	Gymnasium	SwimmingPool	LandscapedGardens	JoggingTrack	...	GolfCourse	TV	DiningTable	Sofa	Wardrobe	Refrigerator	Furniture	Fitness	Appliances	Entertain
UID	1.000000	0.064850	0.063071	0.051480	0.212599	-0.000520	0.088414	0.055945	-0.058220	-0.038571	...	-0.007931	0.057311	0.057311	0.057311	NaN	0.057311	0.058585	0.123987	0.057954	0.057296
Price	0.064850	1.000000	0.904116	0.529604	-0.083060	0.011691	0.080747	0.149025	-0.015412	0.148941	...	0.082279	0.131400	0.131400	0.131400	NaN	0.131400	0.132249	0.212432	0.131750	0.084318
44 rows × 44 columns

1
sns.set(rc={'figure.figsize':(12,12)})
2
sns.heatmap(places.corr(), annot=True)
<AxesSubplot:>

1.5  One way ANOVA Analysis
This is a one way anova test. The categorical variable is the Region and I'm studying the effect of how the 'neighborhood' has on the price of the housing. The results show me that there is a region that has average house price that is different than the rest of the regions because the p value is so small.

1
stats.f_oneway(places['Price'][places['Region'] == 'Central'],
2
               places['Price'][places['Region'] == 'West'],
3
               places['Price'][places['Region'] == 'Southeast'],
4
               places['Price'][places['Region'] == 'East'],
5
               places['Price'][places['Region'] == 'Northeast'],
6
               places['Price'][places['Region'] == 'North'],
7
               places['Price'][places['Region'] == 'South'])
8
​
F_onewayResult(statistic=18.489207578925882, pvalue=5.743649647901988e-21)
1.5.1  Anova Table
In continuation of the one way anova test, here is the table of the sum of squares. The f test gives us a test statistic of 18.5 and a p value of 5.74x10^-21 that is caused because of the discrepencies between the central region and the rest of Bangalore as we reviewed in the above graph.

This is a summary of descriptive statistics for price by region such as average price and standard deviation and percentiles by region. I broke the regions down based on the concentration of neighhood groupings. (Central, East, North, Northeast, South, Southeast, and West). We can clearly see that the Central region is the most expensive with an average prices almost double that of the other regions. The number of houses in that regions was 505 that made it the 2nd largest after the South regions, that was actually a region with a low average price. The Central region has also the highest standard deviation that tells me that there are many different types of housing in that area and both ends of the prices. The maximun price in Central is 4 times the maximun price of the next regions which is South.

1
#one way anova by region
2
​
3
model = ols('Price ~ C(Region)', data=places).fit()
4
aov_table = sm.stats.anova_lm(model, typ=2)
5
aov_table
sum_sq	df	F	PR(>F)
C(Region)	1.834667e+16	6.0	18.489208	5.743650e-21
Residual	3.057910e+17	1849.0	NaN	NaN
1
print(places['Price'].groupby(places['Region']).describe().reset_index())
      Region  count          mean           std        min        25%  \
0    Central  505.0  1.478950e+07  2.261382e+07  2096000.0  5559000.0   
1       East  175.0  8.738960e+06  6.979373e+06  2814000.0  4718500.0   
2      North  186.0  1.014567e+07  5.945566e+06  4866000.0  6959750.0   
3  Northeast   31.0  5.913710e+06  2.801731e+06  3372999.0  3856499.5   
4      South  620.0  7.859268e+06  6.051693e+06  2157000.0  4515750.0   
5  Southeast  142.0  8.061746e+06  8.143323e+06  2436000.0  3365250.0   
6       West  197.0  6.357218e+06  1.997640e+06  3800000.0  5089000.0   

         50%         75%          max  
0  7423000.0  13899999.0  202700000.0  
1  6221000.0   8954000.0   37500000.0  
2  8686500.0  10675000.0   44900000.0  
3  4800000.0   6999000.0   14800000.0  
4  6648000.0   8749000.0   69000000.0  
5  5184000.0  10200750.0   45700000.0  
6  5600000.0   7252000.0   13600000.0  
1.5.2  Tukey HSD Test
The results of the one way anova test showed that there are significant differences in the average price by region. Now I perform a Tukey HSD test to help identify which regions exhibit different average prices assuming equal variances.

1
tukey = pairwise_tukeyhsd(places['Price'],
2
                          places['Region']
3
                          )
4
print(tukey)
            Multiple Comparison of Means - Tukey HSD, FWER=0.05             
============================================================================
  group1    group2     meandiff   p-adj      lower          upper     reject
----------------------------------------------------------------------------
  Central      East -6050540.9573  0.001  -9380070.8469 -2721011.0676   True
  Central     North -4643834.3051  0.001  -7899426.7917 -1388241.8184   True
  Central Northeast -8875791.3481 0.0037 -15899217.7185 -1852364.9776   True
  Central     South -6930233.2545  0.001  -9205476.8598 -4654989.6492   True
  Central Southeast -6727754.4991  0.001 -10333171.1002 -3122337.8981   True
  Central      West -8432282.6749  0.001 -11620757.0347 -5243808.3151   True
     East     North  1406706.6522    0.9  -2590635.0974  5404048.4019  False
     East Northeast -2825250.3908    0.9 -10221761.5011  4571260.7195  False
     East     South  -879692.2972    0.9  -4128783.2605   2369398.666  False
     East Southeast  -677213.5419    0.9  -4964274.0139  3609846.9302  False
     East      West -2381741.7176 0.5513  -6324612.1653    1561128.73  False
    North Northeast  -4231957.043 0.6021 -11595481.3187  3131567.2326  False
    North     South -2286398.9495 0.3373  -5459678.8364   886880.9375  False
    North Southeast -2083920.1941 0.7444  -6313813.8859  2145973.4978  False
    North      West -3788448.3698 0.0611  -7669084.9826    92188.2429  False
Northeast     South  1945558.0935    0.9  -5040094.4016  8931210.5886  False
Northeast Southeast  2148036.8489    0.9  -5376698.1089  9672771.8068  False
Northeast      West   443508.6732    0.9  -6890588.1398  7777605.4861  False
    South Southeast   202478.7554    0.9  -3328788.9587  3733746.4695  False
    South      West -1502049.4204 0.7597  -4606432.0554  1602333.2146  False
Southeast      West -1704528.1758 0.8913  -5882983.2668  2473926.9153  False
----------------------------------------------------------------------------
Here is a graph of the Tukey results. The graph shows us that the difference in average price is small but higher cost in the Central in comparision with every other region.The East, Southeast, South, and West regions have similar averages and ranges of prices. North region has slightly higher prices. Northeast has a big range. While Central is not similar to any of the others with the mean price being much higher than all the others.

1
#Why does it make 2 graphs?
2
placesdata = MultiComparison(places['Price'], places['Region'])
3
results = placesdata.tukeyhsd() 
4
results.plot_simultaneous()
5
​
C:\Users\Tom\anaconda3\lib\site-packages\statsmodels\sandbox\stats\multicomp.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
  ax1.set_yticklabels(np.insert(self.groupsunique.astype(str), 0, ''))


1.5.3  Levene Test
Reviewing the variances of the different regions and we can see that the central region again is different than all the others.

1
#Ran levene test
2
stats.levene(places['Price'][places['Region'] == 'Central'],
3
               places['Price'][places['Region'] == 'West'],
4
               places['Price'][places['Region'] == 'Southeast'],
5
               places['Price'][places['Region'] == 'East'],
6
               places['Price'][places['Region'] == 'Northeast'],
7
               places['Price'][places['Region'] == 'North'],
8
               places['Price'][places['Region'] == 'South'])
LeveneResult(statistic=16.164134399434975, pvalue=3.303428680
